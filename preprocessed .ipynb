# %%
import pandas as pd
import numpy as np

# %%
brfss = pd.read_csv('preprocessed_final.csv')
df = brfss.drop(['Unnamed: 0'], axis=1)

df
# Out:
#         _STATE  LADULT1  SEXVAR  GENHLTH  PHYSHLTH  MENTHLTH  PRIMINSR  \
# 0            1      1.0       2      5.0      20.0      10.0       3.0
# 1            1      1.0       2      3.0      88.0      88.0       1.0
# 2            1      1.0       2      2.0      88.0      88.0       2.0
# 3            1      1.0       2      2.0      88.0      10.0       2.0
# 4            1      1.0       1      5.0      30.0      88.0       3.0
# ...        ...      ...     ...      ...       ...       ...       ...
# 109188      78      1.0       2      1.0      88.0      88.0       1.0
# 109189      78      1.0       2      2.0      88.0      88.0      88.0
# 109190      78      1.0       2      2.0      88.0      88.0       3.0
# 109191      78      1.0       2      4.0      77.0      77.0       3.0
# 109192      78      1.0       2      3.0      77.0      88.0       3.0
#
#         PERSDOC3  MEDCOST1  CHECKUP1  ...  _SMOKER3  _RFSMOK3  _CURECI1  \
# ...

# %% [markdown]
# # MatLab State Labels

# %%
values = df['_STATE'].unique()

# for x in values:
# #     for y in range(0, len(values))
#     ML = df.loc[df['_STATE'] == x]
#     state = x
#     file = f"df_state_L{state}.csv"
#     ML.to_csv(file)
    
# for x in values:
#     line = f"M_LS{x} = readmatrix('df_state_L{x}.csv');"
#     print(line)

# for x in values:
#     line = f" M_LS{x}(2:end, [2:end-1]),"
#     print(line)

for x in values:
    line = f" M_LS{x}(2:end, end),"
    print(line)
# Out:
#  M_LS1(2:end, end),
#  M_LS2(2:end, end),
#  M_LS4(2:end, end),
#  M_LS5(2:end, end),
#  M_LS6(2:end, end),
#  M_LS8(2:end, end),
#  M_LS9(2:end, end),
#  M_LS10(2:end, end),
#  M_LS11(2:end, end),
#  M_LS13(2:end, end),
#  M_LS15(2:end, end),
#  M_LS16(2:end, end),
#  M_LS17(2:end, end),
#  M_LS18(2:end, end),
#  M_LS19(2:end, end),
#  M_LS20(2:end, end),
#  M_LS21(2:end, end),
#  M_LS22(2:end, end),
#  M_LS23(2:end, end),
#  M_LS24(2:end, end),
#  M_LS25(2:end, end),
#  M_LS26(2:end, end),
#  M_LS27(2:end, end),
#  M_LS28(2:end, end),
#  M_LS29(2:end, end),
#  M_LS30(2:end, end),
#  M_LS31(2:end, end),
#  M_LS32(2:end, end),
#  M_LS33(2:end, end),
#  M_LS34(2:end, end),
#  M_LS35(2:end, end),
#  M_LS36(2:end, end),
#  M_LS37(2:end, end),
#  M_LS38(2:end, end),
#  M_LS39(2:end, end),
#  M_LS40(2:end, end),
#  M_LS41(2:end, end),
#  M_LS42(2:end, end),
#  M_LS44(2:end, end),
#  M_LS45(2:end, end),
#  M_LS46(2:end, end),
#  M_LS47(2:end, end),
#  M_LS48(2:end, end),
# ...

# %% [markdown]
# # Computed Mental Health Datasets

# %%
ML1 = df.loc[df['_MENT14D'] == 1]
ML1.to_csv("df_computed_mental_health_L1_0days.csv")

ML1
# Out:
#         _STATE  LADULT1  SEXVAR  GENHLTH  PHYSHLTH  MENTHLTH  PRIMINSR  \
# 1            1      1.0       2      3.0      88.0      88.0       1.0
# 2            1      1.0       2      2.0      88.0      88.0       2.0
# 4            1      1.0       1      5.0      30.0      88.0       3.0
# 5            1      1.0       1      3.0      88.0      88.0       3.0
# 6            1      1.0       1      3.0      30.0      88.0       1.0
# ...        ...      ...     ...      ...       ...       ...       ...
# 109187      78      1.0       2      2.0      88.0      88.0       3.0
# 109188      78      1.0       2      1.0      88.0      88.0       1.0
# 109189      78      1.0       2      2.0      88.0      88.0      88.0
# 109190      78      1.0       2      2.0      88.0      88.0       3.0
# 109192      78      1.0       2      3.0      77.0      88.0       3.0
#
#         PERSDOC3  MEDCOST1  CHECKUP1  ...  _SMOKER3  _RFSMOK3  _CURECI1  \
# ...

# %%
ML2 = df.loc[df['_MENT14D'] == 2]
ML2.to_csv("df_computed_mental_health_L2_1to13days.csv")

ML2
# Out:
#         _STATE  LADULT1  SEXVAR  GENHLTH  PHYSHLTH  MENTHLTH  PRIMINSR  \
# 0            1      1.0       2      5.0      20.0      10.0       3.0
# 3            1      1.0       2      2.0      88.0      10.0       2.0
# 9            1      1.0       2      3.0      25.0       5.0       3.0
# 29           1      1.0       2      3.0       4.0       2.0       3.0
# 30           1      1.0       2      2.0      88.0       3.0       1.0
# ...        ...      ...     ...      ...       ...       ...       ...
# 109163      78      1.0       1      2.0       5.0       4.0       3.0
# 109166      78      1.0       1      5.0      15.0      11.0       3.0
# 109178      78      1.0       2      2.0       4.0       5.0       3.0
# 109179      78      1.0       2      2.0      88.0       6.0       3.0
# 109186      78      1.0       2      3.0      88.0      10.0       3.0
#
#         PERSDOC3  MEDCOST1  CHECKUP1  ...  _SMOKER3  _RFSMOK3  _CURECI1  \
# ...

# %%
ML3 = df.loc[df['_MENT14D'] == 3]
ML3.to_csv("df_computed_mental_health_L3_14plusdays.csv")

ML3
# Out:
#         _STATE  LADULT1  SEXVAR  GENHLTH  PHYSHLTH  MENTHLTH  PRIMINSR  \
# 10           1      1.0       2      4.0      88.0      25.0       3.0
# 11           1      1.0       2      3.0       7.0      15.0       3.0
# 24           1      1.0       2      4.0       4.0      14.0       3.0
# 62           1      1.0       2      4.0      15.0      30.0       3.0
# 64           1      1.0       2      4.0       2.0      25.0       1.0
# ...        ...      ...     ...      ...       ...       ...       ...
# 109139      78      1.0       2      3.0      14.0      30.0       2.0
# 109146      78      1.0       2      5.0       5.0      30.0      88.0
# 109181      78      1.0       2      2.0      88.0      14.0      10.0
# 109183      78      1.0       2      4.0      30.0      30.0       1.0
# 109184      78      1.0       2      2.0      88.0      30.0       5.0
#
#         PERSDOC3  MEDCOST1  CHECKUP1  ...  _SMOKER3  _RFSMOK3  _CURECI1  \
# ...

# %%
df2 = pd.read_excel('W_MTL_Least_L21__MENT14D.xlsx')

# df2.set_axis(['index', 'Mental_1', 'Mental_2', 'Mental_3'], axis =1)
df2 = df2.drop(['index'], axis =1)

df2
# Out:
#        Mental_1     Mental_2     Mental_3
# 0  -4738.308360  5595.460153  5208.201157
# 1    153.808541   769.080229   385.871910
# 2   -115.939854  1164.017712   605.088267
# 3    913.125638  1922.765675  1272.485498
# 4  -1046.612782 -1967.645710 -4221.000580
# ..          ...          ...          ...
# 75  -742.836628    57.921214  6750.531813
# 76    -0.149205    -1.350843    -4.275085
# 77   812.006363  1011.354136   523.610928
# 78   951.791616  1167.557185   706.972661
# 79   512.444650   691.724188   498.368886
#
# [80 rows x 3 columns]

# %%
cols = df.columns
cols = cols.drop(['_RFBING5'])

cols
# Out:
# Index(['_STATE', 'LADULT1', 'SEXVAR', 'GENHLTH', 'PHYSHLTH', 'MENTHLTH',
#        'PRIMINSR', 'PERSDOC3', 'MEDCOST1', 'CHECKUP1', 'EXERANY2', 'BPHIGH6',
#        'CHOLCHK3', 'CVDINFR4', 'CVDCRHD4', 'CVDSTRK3', 'ASTHMA3', 'CHCSCNCR',
#        'CHCOCNCR', 'CHCCOPD3', 'ADDEPEV3', 'CHCKDNY2', 'DIABETE4', 'HAVARTH5',
#        'MARITAL', 'EDUCA', 'RENTHOM1', 'NUMHHOL3', 'VETERAN3', 'EMPLOY1',
#        'CHILDREN', 'WEIGHT2', 'HEIGHT3', 'DEAF', 'BLIND', 'DECIDE', 'DIFFWALK',
#        'DIFFDRES', 'DIFFALON', 'SMOKE100', 'USENOW3', 'ALCDAY5', '_IMPRACE',
#        '_DUALUSE', '_RFHLTH', '_PHYS14D', '_MENT14D', '_HLTHPLN', '_HCVU652',
#        '_TOTINDA', '_RFHYPE6', '_CHOLCH3', '_LTASTH1', '_CASTHM1', '_ASTHMS1',
#        '_PRACE1', '_MRACE1', '_HISPANC', '_RACE', '_RACEG21', '_RACEGR3',
#        '_RACEPRV', '_SEX', '_AGEG5YR', '_AGE65YR', '_AGE80', '_AGE_G',
#        '_RFBMI5', '_CHLDCNT', '_EDUCAG', '_INCOMG1', '_SMOKER3', '_RFSMOK3',
# ...

# %%
df2['L1_Risk_Factors'] = cols
df2
# Out:
#        Mental_1     Mental_2     Mental_3 L1_Risk_Factors
# 0  -4738.308360  5595.460153  5208.201157          _STATE
# 1    153.808541   769.080229   385.871910         LADULT1
# 2   -115.939854  1164.017712   605.088267          SEXVAR
# 3    913.125638  1922.765675  1272.485498         GENHLTH
# 4  -1046.612782 -1967.645710 -4221.000580        PHYSHLTH
# ..          ...          ...          ...             ...
# 75  -742.836628    57.921214  6750.531813        DROCDY3_
# 76    -0.149205    -1.350843    -4.275085        _DRNKWK1
# 77   812.006363  1011.354136   523.610928        _RFDRHV7
# 78   951.791616  1167.557185   706.972661        _FRTLT1A
# 79   512.444650   691.724188   498.368886        _VEGLT1A
#
# [80 rows x 4 columns]

# %%
SM1 = df2.sort_values(by = ['Mental_1'], ascending = False)

for x in range(0, len(SM1)):
    print(SM1['L1_Risk_Factors'][x])
SM1
# Out:
# _STATE
# LADULT1
# SEXVAR
# GENHLTH
# PHYSHLTH
# MENTHLTH
# PRIMINSR
# PERSDOC3
# MEDCOST1
# CHECKUP1
# EXERANY2
# BPHIGH6
# CHOLCHK3
# CVDINFR4
# CVDCRHD4
# CVDSTRK3
# ASTHMA3
# CHCSCNCR
# CHCOCNCR
# CHCCOPD3
# ADDEPEV3
# CHCKDNY2
# DIABETE4
# HAVARTH5
# MARITAL
# EDUCA
# RENTHOM1
# NUMHHOL3
# VETERAN3
# EMPLOY1
# CHILDREN
# WEIGHT2
# HEIGHT3
# DEAF
# BLIND
# DECIDE
# DIFFWALK
# DIFFDRES
# DIFFALON
# SMOKE100
# USENOW3
# ALCDAY5
# _IMPRACE
# _DUALUSE
# _RFHLTH
# _PHYS14D
# _MENT14D
# _HLTHPLN
# _HCVU652
# _TOTINDA
# _RFHYPE6
# _CHOLCH3
# _LTASTH1
# _CASTHM1
# _ASTHMS1
# _PRACE1
# _MRACE1
# _HISPANC
# _RACE
# _RACEG21
# _RACEGR3
# _RACEPRV
# _SEX
# _AGEG5YR
# _AGE65YR
# _AGE80
# _AGE_G
# _RFBMI5
# _CHLDCNT
# _EDUCAG
# _INCOMG1
# _SMOKER3
# _RFSMOK3
# _CURECI1
# DRNKANY5
# DROCDY3_
# _DRNKWK1
# _RFDRHV7
# _FRTLT1A
# _VEGLT1A
#         Mental_1     Mental_2     Mental_3 L1_Risk_Factors
# 5   13034.216088  4087.157263  7362.392939        MENTHLTH
# ...

# %% [markdown]
# # Binge Drinking Calculated Variable Datasets

# %%
mental = df.pop('_MENT14D')
df.insert(len(df.columns), '_MENT14D', mental)

df
# Out:
#         _STATE  LADULT1  SEXVAR  GENHLTH  PHYSHLTH  MENTHLTH  PRIMINSR  \
# 0            1      1.0       2      5.0      20.0      10.0       3.0
# 1            1      1.0       2      3.0      88.0      88.0       1.0
# 2            1      1.0       2      2.0      88.0      88.0       2.0
# 3            1      1.0       2      2.0      88.0      10.0       2.0
# 4            1      1.0       1      5.0      30.0      88.0       3.0
# ...        ...      ...     ...      ...       ...       ...       ...
# 109188      78      1.0       2      1.0      88.0      88.0       1.0
# 109189      78      1.0       2      2.0      88.0      88.0      88.0
# 109190      78      1.0       2      2.0      88.0      88.0       3.0
# 109191      78      1.0       2      4.0      77.0      77.0       3.0
# 109192      78      1.0       2      3.0      77.0      88.0       3.0
#
#         PERSDOC3  MEDCOST1  CHECKUP1  ...  _RFSMOK3  _CURECI1  DRNKANY5  \
# ...

# %%
ML4 = df.loc[df['_RFBING5'] == 1]
ML4.to_csv("df_binge_drinking_calculated_variable_L1_no.csv")

ML4
# Out:
#         _STATE  LADULT1  SEXVAR  GENHLTH  PHYSHLTH  MENTHLTH  PRIMINSR  \
# 0            1      1.0       2      5.0      20.0      10.0       3.0
# 1            1      1.0       2      3.0      88.0      88.0       1.0
# 2            1      1.0       2      2.0      88.0      88.0       2.0
# 4            1      1.0       1      5.0      30.0      88.0       3.0
# 5            1      1.0       1      3.0      88.0      88.0       3.0
# ...        ...      ...     ...      ...       ...       ...       ...
# 109188      78      1.0       2      1.0      88.0      88.0       1.0
# 109189      78      1.0       2      2.0      88.0      88.0      88.0
# 109190      78      1.0       2      2.0      88.0      88.0       3.0
# 109191      78      1.0       2      4.0      77.0      77.0       3.0
# 109192      78      1.0       2      3.0      77.0      88.0       3.0
#
#         PERSDOC3  MEDCOST1  CHECKUP1  ...  _RFSMOK3  _CURECI1  DRNKANY5  \
# ...

# %%
ML5 = df.loc[df['_RFBING5'] == 2]
ML5.to_csv("df_binge_drinking_calculated_variable_L2_yes.csv")

ML5
# Out:
#         _STATE  LADULT1  SEXVAR  GENHLTH  PHYSHLTH  MENTHLTH  PRIMINSR  \
# 3            1      1.0       2      2.0      88.0      10.0       2.0
# 58           1      1.0       1      2.0      88.0      88.0       1.0
# 69           1      1.0       1      3.0       3.0      88.0       3.0
# 95           1      1.0       2      4.0      10.0      10.0       1.0
# 96           1      1.0       2      3.0      88.0       2.0       2.0
# ...        ...      ...     ...      ...       ...       ...       ...
# 109079      78      1.0       2      3.0       4.0       4.0       3.0
# 109102      78      1.0       2      1.0      88.0      88.0      88.0
# 109103      78      1.0       1      1.0      88.0       3.0       1.0
# 109161      78      1.0       1      3.0       5.0      88.0       3.0
# 109186      78      1.0       2      3.0      88.0      10.0       3.0
#
#         PERSDOC3  MEDCOST1  CHECKUP1  ...  _RFSMOK3  _CURECI1  DRNKANY5  \
# ...

# %%
# df2 = pd.read_excel('W_MTL_Least_L21__RBFING5.xlsx')

# # df2.set_axis(['index', 'Mental_1', 'Mental_2', 'Mental_3'], axis =1)
# df2 = df2.drop(['index'], axis =1)

# df2

# %% [markdown]
# # Number of Days having at least one drink Datasets

# %%
# lol = df['ALCDAY5'].unique()
# print(lol)

ML6 = df.loc[df['ALCDAY5'] == 888]
ML6.to_csv("df_days_in_past_30_had_alcoholic_drink_L1_nodrinks.csv")

ML6
# Out:
#         _STATE  LADULT1  SEXVAR  GENHLTH  PHYSHLTH  MENTHLTH  PRIMINSR  \
# 0            1      1.0       2      5.0      20.0      10.0       3.0
# 1            1      1.0       2      3.0      88.0      88.0       1.0
# 2            1      1.0       2      2.0      88.0      88.0       2.0
# 4            1      1.0       1      5.0      30.0      88.0       3.0
# 5            1      1.0       1      3.0      88.0      88.0       3.0
# ...        ...      ...     ...      ...       ...       ...       ...
# 109185      78      1.0       2      4.0      88.0      88.0       3.0
# 109188      78      1.0       2      1.0      88.0      88.0       1.0
# 109190      78      1.0       2      2.0      88.0      88.0       3.0
# 109191      78      1.0       2      4.0      77.0      77.0       3.0
# 109192      78      1.0       2      3.0      77.0      88.0       3.0
#
#         PERSDOC3  MEDCOST1  CHECKUP1  ...  _RFSMOK3  _CURECI1  DRNKANY5  \
# ...

# %%
ML7 = df.loc[df['ALCDAY5'].between(101, 107, inclusive = True)]
ML7.to_csv("df_days_in_past_30_had_alcoholic_drink_L2_1dayPerWeek.csv")

ML7
# Out:
# C:\Users\hnr59\AppData\Local\Temp\ipykernel_11640\962167887.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   ML7 = df.loc[df['ALCDAY5'].between(101, 107, inclusive = True)]
#         _STATE  LADULT1  SEXVAR  GENHLTH  PHYSHLTH  MENTHLTH  PRIMINSR  \
# 3            1      1.0       2      2.0      88.0      10.0       2.0
# 19           1      1.0       2      2.0      88.0      88.0       1.0
# 35           1      1.0       2      3.0       2.0      88.0       1.0
# 64           1      1.0       2      4.0       2.0      25.0       1.0
# 90           1      1.0       2      4.0      10.0      20.0       3.0
# ...        ...      ...     ...      ...       ...       ...       ...
# 109145      78      1.0       2      2.0      77.0       3.0       1.0
# 109155      78      1.0       2      1.0      88.0      88.0      88.0
# 109161      78      1.0       1      3.0       5.0      88.0       3.0
# ...

# %%
ML8 = df.loc[df['ALCDAY5'].between(201, 230, inclusive = True)]
ML8.to_csv("df_days_in_past_30_had_alcoholic_drink_L3_daysin30.csv")

ML8
# Out:
# C:\Users\hnr59\AppData\Local\Temp\ipykernel_11640\2735191838.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   ML8 = df.loc[df['ALCDAY5'].between(201, 230, inclusive = True)]
#         _STATE  LADULT1  SEXVAR  GENHLTH  PHYSHLTH  MENTHLTH  PRIMINSR  \
# 9            1      1.0       2      3.0      25.0       5.0       3.0
# 21           1      1.0       1      4.0      88.0      88.0       3.0
# 23           1      1.0       1      5.0      30.0      88.0       3.0
# 27           1      1.0       1      2.0      88.0      88.0       3.0
# 28           1      1.0       1      4.0      88.0      88.0       3.0
# ...        ...      ...     ...      ...       ...       ...       ...
# 109175      78      1.0       2      5.0      30.0      88.0       3.0
# 109179      78      1.0       2      2.0      88.0       6.0       3.0
# 109184      78      1.0       2      2.0      88.0      30.0       5.0
# ...
